# %%
import json
import pandas as pd
import numpy as np

# %%
d = json.load(open('/Users/stefan/Downloads/phase1-data.json'))

# %%
del d['Stefan, Wed Nov 14 2018 19:17:18 GMT-0800 (Pacific Standard Time)']

# %%
def iterate_replays(variant_d, key):
    for replay in [k for k in variant_d if k.startswith('replay')]:
        if key in variant_d[replay]:
            yield variant_d[replay][key]

# %%
variant_rows = []
user_rows = []

for user in d:
    u = user.split(',')[0]

    affective_variant = 3 if d[user]['variant-3']['replay-1']['game_type'] == 'Affective' else 4
    
    for variant in [k for k in d[user] if k.startswith('variant')]:
        ratings = d[user][variant]['ratings']

        scores = [
            len(xs)
            for xs in iterate_replays(d[user][variant], 'x')
        ]
        replay_durations = [
            (int(times[-1]) - int(times[0])) / 1000
            for times in iterate_replays(d[user][variant], 'time')
        ]
        
        
        variant_rows.append({
            'user': u,
            'variant': int(variant[-1]),
            
            'max_score': max(scores),
            'avg_score': sum(scores) / len(scores),
            'total_duration': sum(replay_durations),
            **ratings
        })
    
    user_rows.append({
        'user': u,
        'rated_best_variant': d[user]['subjectInfo']['bestVariant'],
        'affective_variant': affective_variant,  # it is the same across all replays, so we just look at the first one
        'affective_variant_first': affective_variant == 3,
    })

variant_df = pd.DataFrame(variant_rows)
user_df = pd.DataFrame(user_rows).set_index('user')

# %%
variant_df
# Out:
#     avg_score  difficulty  enjoyment  max_score  total_duration  \
# 0   15.333333           3          5         17          57.231
# 1    7.666667           5          5         11          30.487
# 2    7.500000           4          5         10          42.732
# 3    6.600000           5          4          8          51.013
# 4   23.333333           3          4         25          86.746
# 5    9.666667           5          4         10          32.377
# 6   18.800000           4          4         24         133.398
# 7   14.333333           4          4         16          53.780
# 8   25.500000           3          4         30          63.591
# 9    8.000000           5          5         10          16.074
# 10  11.100000           3          5         21         160.301
# 11  13.142857           4          4         18         121.694
# 12  22.000000           3          4         23         115.881
# 13  10.000000           5          4         10          72.287
# 14  12.250000           4          3         16         192.293
# 15   7.500000           4          3         11         103.286
# 16  38.000000           2          4         38         159.699
# 17   6.000000           5          3          7          13.978
# 18  15.200000           4          4         20          89.305
# 19  11.666667           4          3         15          45.346
# 20   5.500000           1          3          8          27.399
# 21   4.000000           3          3          4           4.321
# 22   7.500000           3          3         11          29.089
# 23   5.571429           3          3          8          28.965
# 24  26.500000           3          4         32         112.621
# 25   8.500000           5          2          9          22.285
# 26  14.250000           4          3         17          94.362
# 27  11.200000           4          4         15          62.908
# 28  28.000000           4          2         35         119.838
# 29  11.500000           5          3         12          30.597
# 30  12.000000           4          3         17          43.489
# 31  11.333333           4          2         23          59.906
# 32  26.000000           2          2         29         125.935
# 33   4.500000           4          3          5          23.345
# 34  10.200000           3          3         17          76.686
# 35  10.333333           3          2         14          71.690
# 36  23.500000           3          4         25          61.389
# 37  15.000000           4          4         18          35.152
# 38  12.333333           4          4         18          98.578
# 39  19.333333           4          4         23         167.149
#
#              user  valence  variant
# 0        Anupriya        4        1
# 1        Anupriya        5        2
# 2        Anupriya        5        3
# 3        Anupriya        4        4
# 4          Daniel        4        1
# 5          Daniel        3        2
# 6          Daniel        4        3
# 7          Daniel        3        4
# 8      Jared Zhao        4        1
# 9      Jared Zhao        3        2
# 10     Jared Zhao        4        3
# 11     Jared Zhao        4        4
# 12       Jiaoyang        3        1
# 13       Jiaoyang        5        2
# 14       Jiaoyang        4        3
# 15       Jiaoyang        4        4
# 16      Justin Ly        4        1
# 17      Justin Ly        1        2
# 18      Justin Ly        2        3
# 19      Justin Ly        3        4
# 20          Minha        3        1
# 21          Minha        3        2
# 22          Minha        3        3
# 23          Minha        3        4
# 24     Serena Zhu        5        1
# 25     Serena Zhu        2        2
# 26     Serena Zhu        3        3
# 27     Serena Zhu        3        4
# 28   Timothy Wang        2        1
# 29   Timothy Wang        4        2
# 30   Timothy Wang        4        3
# 31   Timothy Wang        2        4
# 32          Yilei        3        1
# 33          Yilei        4        2
# 34          Yilei        3        3
# 35          Yilei        3        4
# 36  jeffrey stone        5        1
# 37  jeffrey stone        4        2
# 38  jeffrey stone        4        3
# 39  jeffrey stone        4        4

# %%
for user, user_rows in variant_df.groupby('user'):
    highest_score_rows = user_rows[user_rows.max_score == user_rows.max_score.max()]
    highest_score = highest_score_rows.max_score.iloc[0]
    highest_variant = highest_score_rows.variant.iloc[0]
    if len(highest_score_rows) > 1:
        print(f'{user} has the same highest score ({highest_score}) on multiple variants: {highest_score_rows.variant.tolist()}')
        
    user_df.loc[user, 'highest_score_variant'] = highest_variant
    
    affective_variant_row = user_rows[user_rows.variant == user_df.loc[user].affective_variant].iloc[0]
    classic_variant = 3 + 4-affective_variant_row.variant
    classic_variant_row = user_rows[user_rows.variant == classic_variant].iloc[0]
    
    user_df.loc[user, 'affective_variant_duration'] = affective_variant_row.total_duration
    user_df.loc[user, 'classic_variant_duration'] = classic_variant_row.total_duration

# %%
user_df
# Out:
#                affective_variant  affective_variant_first  rated_best_variant  \
# user
# Anupriya                       3                     True                   3
# Daniel                         4                    False                   3
# Jared Zhao                     4                    False                   1
# Jiaoyang                       4                    False                   1
# Justin Ly                      4                    False                   1
# Minha                          4                    False                   4
# Serena Zhu                     4                    False                   1
# Timothy Wang                   3                     True                   3
# Yilei                          4                    False                   1
# jeffrey stone                  3                     True                   1
#
#                highest_score_variant  affective_variant_duration  \
# user
# Anupriya                         1.0                      42.732
# Daniel                           1.0                      53.780
# Jared Zhao                       1.0                     121.694
# Jiaoyang                         1.0                     103.286
# Justin Ly                        1.0                      45.346
# Minha                            3.0                      28.965
# Serena Zhu                       1.0                      62.908
# Timothy Wang                     1.0                      43.489
# Yilei                            1.0                      71.690
# jeffrey stone                    1.0                      98.578
#
#                classic_variant_duration
# user
# Anupriya                         51.013
# Daniel                          133.398
# Jared Zhao                      160.301
# Jiaoyang                        192.293
# Justin Ly                        89.305
# Minha                            29.089
# Serena Zhu                       94.362
# Timothy Wang                     59.906
# Yilei                            76.686
# jeffrey stone                   167.149

# %%
f'{(user_df.rated_best_variant == user_df.highest_score_variant).mean():.0%} users rated their highest scoring variant as the best one'
# Out:
# '60% users rated their highest scoring variant as the best one'

# %%
f'{(user_df.highest_score_variant == 1).mean():.0%} got their highest score on the easiest variant'
# Out:
# '90% got their highest score on the easiest variant'

# %%
f'{(user_df.rated_best_variant == user_df.affective_variant).mean():.0%} users rated the affective variant as the best one'
# Out:
# '30% users rated the affective variant as the best one'

# %%
f'{(user_df.affective_variant_duration > user_df.classic_variant_duration).mean():.0%} users played the physiologically-adaptive variant longer than the classically-adaptive one'
# Out:
# '0% users played the physiologically-adaptive variant longer than the classically-adaptive one'
